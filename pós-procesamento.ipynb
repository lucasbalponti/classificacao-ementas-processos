# %%
import pandas as pd
import progressbar
import csv
import re
import pickle

# %%
df = pd.read_csv(r'ementas3.csv').set_index('Unnamed: 0')
df.index.name = None

# %%
# Tratando o texto
widgets = [' [',
         progressbar.Timer(),
         '] ',
           progressbar.Bar('*'),' (',
           progressbar.ETA(), ') ',
          ]
bar = progressbar.ProgressBar(maxval = len(df), widgets=widgets).start()

for linha in range(len(df)):
    # Convertendo para letra minúscula
    df.loc[linha, 'Texto tratado'] = df['Texto semi-tratado'][linha].lower()

    # Removendo os números
    df['Texto tratado'][linha] = re.sub(r'\d', ' ', df['Texto tratado'][linha])

    # Removendo possíveis urls
    df['Texto tratado'][linha] = re.sub(r'https?:\/\/\S+|http?:\/\/\S+', ' ', df['Texto tratado'][linha])
                                        
    # Removendo caracteres especiais mas mantendo letras acentuadas, tios e cedilhas
    df['Texto tratado'][linha] = re.sub(r'[^A-zÀ-ÿ\s]|[\[\]]', ' ', df['Texto tratado'][linha])

    # Removendo espaços duplos
    df['Texto tratado'][linha] = re.sub(r'\s\s+', ' ', df['Texto tratado'][linha]).strip()
    
    bar.update(linha)
# Out:
#  [Elapsed Time: 0:02:07] |********************************** | (ETA:  0:00:00)

# %%
df
# Out:
#                    Assunto                                     Texto original  \
# 0       Direito Tributário  \nEmenta: RECURSOS EXTRAORDINÁRIOS MA APELAÇ20...
# 1       Direito Tributário  \nEmenta: * IMPOSTO - Propriedade Predial e Te...
# 2       Direito Tributário  \nEmenta: ACÓRDÃO\nTRIBUTO - IMPOSTO PREDIAL E...
# 3       Direito Tributário  \nEmenta: ACÓRDÃO\nMANDADO DE SEGURANÇA - IPTU...
# 4       Direito Tributário  \n\n\t\t\t\t\t\t\t\t\t\t\t\t\tEmenta:\n\t\t\t\...
# ...                    ...                                                ...
# 107332       Direito Civil  \nEmenta: ACÓRDÃO\nPROCESSO - Ação Indenizatór...
# 107333       Direito Civil  \n\n\t\t\t\t\t\t\t\t\t\t\t\t\tEmenta:\n\t\t\t\...
# 107334       Direito Civil  \nEmenta: EXTINÇÃO DO PROCESSO - Ação Rescisór...
# 107335       Direito Civil  \nEmenta: AGRAVO DF. INSTRUMENTO. Ação de inde...
# 107336       Direito Civil  \nEmenta: Vistos, relatados e discutidos estes...
#
#                                        Texto semi-tratado  \
# 0       RECURSOS EXTRAORDINÁRIOS MA APELAÇ20 Ne 496.Ô3...
# 1       * IMPOSTO - Propriedade Predial e Territorial ...
# 2       ACÓRDÃO TRIBUTO - IMPOSTO PREDIAL E TERRITORIA...
# 3       ACÓRDÃO MANDADO DE SEGURANÇA - IPTU - Progress...
# 4       IMPOSTO - Predial e Territorial Urbano - Munic...
# ...                                                   ...
# 107332  ACÓRDÃO PROCESSO - Ação Indenizatóría - Afasta...
# 107333  PENHORA - direito de preferência - anteriorida...
# 107334  EXTINÇÃO DO PROCESSO - Ação Rescisória de Acór...
# 107335  AGRAVO DF. INSTRUMENTO. Ação de indenização em...
# 107336  Vistos, relatados e discutidos estes autos de ...
#
#                                             Texto tratado
# 0       recursos extraordinários ma apelaç ne ô í coma...
# 1       imposto propriedade predial e territorial urba...
# 2       acórdão tributo imposto predial e territorial ...
# 3       acórdão mandado de segurança iptu progressivid...
# 4       imposto predial e territorial urbano município...
# ...                                                   ...
# 107332  acórdão processo ação indenizatóría afastada a...
# 107333  penhora direito de preferência anterioridade d...
# 107334  extinção do processo ação rescisória de acórdã...
# 107335  agravo df instrumento ação de indenização em f...
# 107336  vistos relatados e discutidos estes autos de a...
#
# [107337 rows x 4 columns]

# %%
df.to_csv(r'ementas_tratadas.csv')

# %%
with open(r'df-processado.pickle', 'wb') as filepickle:
    pickle.dump(df, filepickle, protocol=pickle.HIGHEST_PROTOCOL)
